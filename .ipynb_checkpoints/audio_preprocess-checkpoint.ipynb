# %%
import audioParse as ap

# %%
# !tar xvfz features.tar.gz | wc -l

# %%
# !curl -O http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# !curl -O http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/class_labels_indices.csv

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class_names = ap.read_labels()
parsed_dataset = ap.read_audio()
# Out:
# Lenght of tfrecord: 1444

# %%
parsed_dataset[1]

# %%
ap.visualize(parsed_dataset, class_names)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/hyegibang/opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/vw/smh4j2rd0nbd3nv6602hrfs40000gn/T/ipykernel_12221/3461503107.py", line 1, in <cell line: 1>
#     ap.visualize(parsed_dataset, class_names)
#   File "/Users/hyegibang/Documents/1470/DL_FinalProject/audioParse.py", line 88, in visualize
#     plt.show()
#   File "/Users/hyegibang/opt/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py", line 409, in show
#     return _get_backend_mod().show(*args, **kwargs)
#   File "/Users/hyegibang/opt/miniconda3/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
# ...

# %%
desired_class = [276,277,278,278,279,280,281,282]
class_names[desired_class]

# %%
music_embeddings = ap.parseEmotionAudio(parsed_dataset2, class_names, desired_class)
print(music_embeddings)

# %%
with open('class_labels_indices.csv', encoding='utf-8') as class_map_csv:
  #class_map_csv = io.StringIO(class_map_csv_text)
  class_names = [display_name for (class_index, mid, display_name) in csv.reader(class_map_csv)]
  class_names = class_names[1:]  # Skip CSV header

class_names = np.array(class_names)

tfrecord_files = os.listdir('audioset_v1_embeddings/bal_train/')
rand_idx = np.random.randint(len(tfrecord_files))

raw_dataset = tf.data.TFRecordDataset(os.path.join('audioset_v1_embeddings/bal_train/',tfrecord_files[rand_idx])) # load random example file

# Create a description of the features.
context = {
    'end_time_seconds': tf.io.FixedLenFeature([], tf.float32, default_value=0.0),
    'video_id': tf.io.FixedLenFeature([], tf.string, default_value=''),
    'start_time_seconds': tf.io.FixedLenFeature([], tf.float32, default_value=0.0),
    'labels': tf.io.VarLenFeature(tf.int64),    
}

sequence = {
    'audio_embedding': tf.io.FixedLenSequenceFeature([], tf.string, default_value=None ,allow_missing=True)
}

def _parse_function(example_proto):
  # Parse the input tf.Example proto using the dictionary above.
  return tf.io.parse_single_sequence_example(example_proto, context_features=context, sequence_features=sequence)

parsed_dataset2 = raw_dataset.map(_parse_function)

# %%
print(parsed_dataset2)
# Out:
# <MapDataset element_spec=({'labels': SparseTensorSpec(TensorShape([None]), tf.int64), 'end_time_seconds': TensorSpec(shape=(), dtype=tf.float32, name=None), 'start_time_seconds': TensorSpec(shape=(), dtype=tf.float32, name=None), 'video_id': TensorSpec(shape=(), dtype=tf.string, name=None)}, {'audio_embedding': TensorSpec(shape=(None,), dtype=tf.string, name=None)})>
