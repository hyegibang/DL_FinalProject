# %%
import imageParse as imgP
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
imageArt, imageArtLabel = imgP.parseData_Art()
print(imageArt.shape)
print(imageArtLabel.shape)
# Out:
# (805, 255, 255, 3)
# (805,)

# %%
from collections import Counter
countLabel = Counter(imageArtLabel)
print(countLabel)
plt.bar(countLabel.keys(), countLabel.values())
plt.title("Histogram of Image Emotions count - total of 806")
# Out:
# Counter({'tender': 172, 'sad': 166, 'scary': 115, 'exciting': 105, 'funny': 101, 'angry': 76, 'happy': 70})
# Text(0.5, 1.0, 'Histogram of Image Emotions count - total of 806')

# %%
VAP_mapping = {
    "happy":(1,0.735,0.772),
    "funny":(0.918,0.61,0.566),
    "sad":(0.225,0.333,0.149),
    "tender":(0.63,0.52,0.509),
    "exciting":(0.95,0.792,0.789),
    "angry":(0.122,0.83,0.604),
    "scary":(0.062,0.952,0.528),
}

# %%
fig_mapping3D = plt.figure()
ax_mapping3D = fig_mapping3D.add_subplot(projection='3d')

# %%
trainImage, trainLabel = imageArt[100:], imageArtLabel[100:]
testImage, testLabel = imageArt[:100], imageArtLabel[:100]
