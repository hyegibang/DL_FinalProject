# %%
import audioParse as ap
# Out:
# 2022-12-06 15:33:36.485526: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !tar xvfz features.tar.gz | wc -l

# %%
# !curl -O http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# !curl -O http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/class_labels_indices.csv

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class_names = ap.read_labels()
parsed_dataset = ap.read_audio()
# Out:
# <TFRecordDatasetV2 element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>
# Lenght of tfrecord: 1444

# %%
ap.visualize(parsed_dataset, class_names)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 ap.visualize(parsed_dataset, class_names)
#
# File ~/Documents/1470/DL_FinalProject/audioParse.py:92, in visualize(parsed_dataset, class_names)
#      90     plt.title(str(class_names[labels]))
#      91     plt.imshow(embedding,cmap='gray')
# ---> 92     plt.show()
#      93 return
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/matplotlib/pyplot.py:421, in show(*args, **kwargs)
#     377 """
#     378 Display all open figures.
#     379
#    (...)
#     418 explicitly there.
#     419 """
#     420 _warn_if_gui_out_of_main_thread()
# --> 421 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %%
desired_class = [276,277,278,278,279,280,281,282]

# %%
happy_music_embeddings, happy_music_contexts, happy_music_label = ap.parsePerEmotion(parsed_dataset, class_names, 276)

# %%
happy_music_embeddings
# Out:
# array([[[ -40,  -95,   88, ...,  109,  115,   73],
#         [ -34, -111,   68, ...,   78, -123,    0],
#         [ -49,  -65,   86, ...,    0,    0,   -1],
#         ...,
#         [ -40, -119,  111, ...,   85,   46,   85],
#         [ -35,  -93,  115, ...,    0,   46,   -1],
#         [ -49,  121,  106, ...,  108,   24,   32]],
#
#        [[ -38,   79,   83, ...,  -45,  -98, -119],
#         [ -13, -121,   81, ...,   95,  -34,   66],
#         [ -19,  -81,   74, ...,  -17,  -52,   -1],
#         ...,
#         [ -18,  -67,   61, ...,  111,   -1,   -1],
#         [ -54,  107,  125, ...,   78,   48,  -91],
#         [ -36,  114,  106, ...,  -53,   60,  -62]],
#
#        [[ -86,   60, -107, ...,  110,  105,   77],
#         [ -60,   71, -104, ...,    0,  126,   70],
#         [ -65,   49,   88, ...,  -46,  107,   39],
#         ...,
#         [ -85,   74,  -99, ...,    0,  125,   12],
#         [ -79,   74, -113, ...,   46,  117,  -85],
# ...

# %%
print(happy_music_embeddings.shape)
# Out:
# (27, 10, 128)

# %%
music_embeddings, music_label = ap.getFullEmotion(parsed_dataset, class_names, desired_class)

# %%
print(len(music_embeddings))
print(len(music_label))
# Out:
# 190
# 190

# %%
print(music_label)
# Out:
# ['scary' 'exciting' 'sad' 'happy' 'sad' 'exciting' 'sad' 'tender' 'tender'
#  'exciting' 'sad' 'funny' 'sad' 'tender' 'exciting' 'funny' 'happy'
#  'angry' 'funny' 'sad' 'exciting' 'happy' 'tender' 'sad' 'funny'
#  'exciting' 'happy' 'exciting' 'happy' 'sad' 'exciting' 'happy' 'sad'
#  'angry' 'angry' 'happy' 'sad' 'sad' 'tender' 'happy' 'happy' 'sad'
#  'exciting' 'sad' 'exciting' 'happy' 'sad' 'sad' 'tender' 'happy' 'sad'
#  'angry' 'sad' 'scary' 'funny' 'tender' 'exciting' 'happy' 'funny' 'sad'
#  'angry' 'sad' 'exciting' 'scary' 'tender' 'funny' 'funny' 'tender'
#  'angry' 'tender' 'happy' 'funny' 'sad' 'tender' 'sad' 'sad' 'funny'
#  'happy' 'funny' 'funny' 'sad' 'tender' 'happy' 'exciting' 'funny'
#  'tender' 'scary' 'scary' 'happy' 'funny' 'exciting' 'exciting' 'tender'
#  'sad' 'angry' 'scary' 'happy' 'tender' 'sad' 'exciting' 'sad' 'tender'
#  'angry' 'scary' 'funny' 'sad' 'funny' 'angry' 'angry' 'scary' 'exciting'
# ...
